# %% [markdown]
# [Next](Dedication.htm) | [Irán Román's Homepage](https://iranroman.github.io/)
#
# ---

# %% [markdown]
# # Deep Learning for Music Information Retrieval #
# Irán R Román
#
# <img align="left" src="DLfMIR_front.png" style="width: 500px" />

# %% [markdown]
# ---
# ## Contents ##
#
# [Dedication](Dedication.htm)
#
# [Preface](Preface.htm)
#
# [Chapter 1: Audio Features and Musical Objects](Audio_Features_and_Musical_Objects.htm)

# %% [markdown]
# ---
#
# [Next](Dedication.htm) | [Irán Román's Homepage](https://iranroman.github.io/)
