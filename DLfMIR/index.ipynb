# %% [markdown]
# # Deep Learning for Music Information Retrieval #
# <img align="left" src="home.png" style="width: 560px" />

# %% [markdown]
# ### 2017 Summer Workshop @ CCRMA ###
# Teaching Staff: [Ankita Mitra](https://www.linkedin.com/in/mitraankita/), [Anish Nag](http://anishnag.com), [Irán Román](https://iranroman.github.io)
#
# Join the discussion and see the leader board: [r/DLfMIR](https://www.reddit.com/r/DLfMIR/)
#
# ---
# ### Meeting Place and Time ###
# [CCRMA](https://ccrma.stanford.edu) (660 Lomita Dr, Stanford, CA), in the classroom (2nd floor).
#
# Monday July 31st through Friday August 4th, daily from 9:30AM to 4:00PM (1.5hr Lunchtime break starting sometime around noon).
#
# #### Meals Included ####
# Breakfast on Monday, Lunch on Thursday, Farewell BBQ Dinner on Friday.

# %% [markdown]
# ---
# ## Contents ##
#
# To gain access to the Workshop's Julia and Tensorflow exercises, type the following command in your prefered location of the Juliabox terminal.
#
# ~~~
# git clone https://github.com/iranroman/DLfMIR_Exercises.git
# ~~~
#
# This will clone to your JuliaBox the remote repository containing the Workshop exercises. If you are new to git and github, feel free to ask the teaching staff for hints on how to keep track of your work and updates made by your instructors to the DLfMIR_Exercises github repository.
#
# After you have cloned the github repository, you can get new content added to the remote repository by typing:
#
# ~~~
# cd DLfMIR_Exercises
# git pull
# ~~~
#
# For more experienced git users: feel free to create your own branch/repo and push your work to it.
#
# Becasue of memory limitations, we don't recommend cloning the repository in Cloud9 (mote info below).
#
# ### Section 1: Classic Problems in MIR meet Deep Learning Solutions ###
# * [Workshop Overview and Math Review](https://docs.google.com/presentation/d/1uWV-Lq4k4oDO-Tj8WRTQiPcR1T4DnHpH9HfPgvn809g/edit?usp=sharing)
# * [The Nearest Neighbors Algorithm (Julia)](https://github.com/iranroman/DLfMIR_Exercises/blob/master/Nearest_Neighbors.ipynb)
# * [The Nearest Neighbors Algorithm (Python)](https://github.com/iranroman/DLfMIR_Exercises/blob/master/KNN.ipynb)
#
# ### Section 2: Anatomy, Physiology and Learning of a Feedforward Neural Network ###
# * [Building a Feedforward Neural Network from Scratch pt1 (Julia)](https://github.com/iranroman/DLfMIR_Exercises/blob/master/Feedforward_NN_from_scratch_pt1.ipynb)
# * [Building a Feedforward Neural Network from Scratch pt2 (Julia)](https://github.com/iranroman/DLfMIR_Exercises/blob/master/Feedforward_NN_from_scratch_pt2.ipynb)
# * [Training a Feedforward Neural Network with Tensorflow (Python)](https://github.com/iranroman/DLfMIR_Exercises/blob/master/Feedforward_NN_tf.ipynb)

# %% [markdown]
# ---
# ### Prerequisites ###
# * Programing experience with Python (and Matlab or Julia)
# * Linear algebra (inner product, partial derivatives, Jacobian matrices)
# * Differential calculus (chain rule)

# %% [markdown]
# ---
# ### Software Set-up ###
# Follow these steps to be prepared:
# * You must have a [github](https://github.com) account. Create one if you don't have one yet (Knowledge of git is not required).
#
# #### Obtaining Julia ####
# * Go to [Juliabox.com](https://juliabox.com) and Sign Up using your github account. That's it! Now you have complete access to Julia. If you haven't used Julia before, don't worry at all. It is a very easy to use language (very similar to matlab)
#
# #### Obtaining Python/Tensorflow ####
# * You can use your prefered IDE if you already have tensorflow installed and you want to stick to your current practice. However, if you haven't used Tensorflow before, we recomment following these steps:
#     1. Sign-up to [Cloud9](https://c9.io) using your github account (you will be asked to authorize Cloud9 to obtain access to your github account). Follow the steps to create a Cloud9 account. You will need to provide credit card information. Although the credit card information is required, all the activites for this workshop will NOT generate charges to your card; we will only be using free Cloud9 features. *
#     2. In the main dashboard, create a new workspace, give it a meaningful name (i.e. mir_tf), and choose a Blank template.
#     3. Once the workspace is open, type the following commands in the bash terminal:
#     ~~~~
#     wget https://repo.continuum.io/miniconda/Miniconda2-latest-Linux-x86_64.sh
#
#     chmod a+x Miniconda2-latest-Linux-x86_64.sh
#
#     ./Miniconda2-latest-Linux-x86_64.sh
#
#     # read and follow all the instructions
#     # type yes to agree with the license agreement
#     # follow the instructions until you see the prompt username:~/workspace
#
#     # Now click the Cloud9 menu in the upper left corner of the browser window and click on 'Restart Workspace'
#     # When the workspace has restarted, continue typing these commands in the bash terminal:
#
#     conda create -n py2 python=2 ipython
#
#     # From this previous step and onwards, always answer to any promts you may be presented with after typing these commands
#
#     source activate py2
#
#     conda install ipython-notebook
#
#     conda install numpy
#
#     conda install scipy
#
#     conda install -c conda-forge tensorflow
#
#     jupyter notebook --ip=0.0.0.0 --port=8080 --no-browser
#
#     # click on the link that appears when the bash terminal halts. A new tab will open and you should see an IDE similar to the one in juliabox.com, but this time with Python and Tensowflow!
#     ~~~~
#
#     4. After you have installed everything in Cloud9, you can close and reopen Cloud9 and your Python/Tensorflow IDE by typing these commands in your workspace:
#
#     ~~~~
#     source activate py2
#
#     jupyter notebook --ip=0.0.0.0 --port=8080 --no-browser
#     ~~~~
#
# *If you decide that you don't want to share your credit card information with Cloud9, you can install python 2.7 and tensorflow to your computer locally. However, we may or may not be able to help you troubleshoot all the steps that this entails, specially with operating systems (like Windows) that the teaching staff has less experience with. Fell free to get in touch if you would like to obtain help.
#
# ---
# ### Datasets ###
#
# We will be working with four datasets, the first one consists of fake data that we will generate on-the-fly in Julia and Python. The other three are available in these links, and you will use them in your Cloud9 workspace.
#
# WARNING: The free Cloud9 memory space is very small (2GB). Therefore, we will be uploading and erasing datasets from Cloud9 as neded. Don't upload any data to Cloud9 until indicated to do so, or you may run out of memory space.
#
# 1. The first dataset we will explore is a small and pre-processed version of the [Iowa Musical Instrument Samples Dataset](http://theremin.music.uiowa.edu/index.html). The goal is to clasify the sounds of instruments based on the timbre of single pitches. The instrument labels are:
#
#     0 'Bass'
#
#     1 'Bassoon'
#
#     2 'Cello'
#
#     3 'Clarinet'
#
#     4 'Flute'
#
#     5 'Guitar'
#
#     6 'Horn'
#
#     7 'Sax'
#
#     8 'Trombone'
#
#     9 'Trumpet'
#
#     10 'Viola'
#
#     11 'Violin'
#
#     Get the small, pre-processed dataset version that we will be using here: [google drive link](https://drive.google.com/open?id=0B1gxPy-6qVriV1FUWUtiZVFUV2s)<br/><br/>
#
# 2. The second dataset we will use is a small version of the [GTZAN](http://marsyasweb.appspot.com/download/data_sets/) music genre dataset. The goal is to classify different genres of music. The genre labels are:
#
#     0 'blues'
#
#     1 'classical'
#
#     2 'country'
#
#     3 'disco'
#
#     4 'hiphop'
#
#     5 'jazz'
#
#     6 'metal'
#
#     7 'pop'
#
#     8 'reggae'
#
#     9 'rock'
#
#     Get the small dataset version that we will be using here: [google drive link](https://drive.google.com/open?id=0B1gxPy-6qVriblhlYTNFS2tXd2s)<br/><br/>
#
# 3. The third datset is one with lyrics. We will use this data to carry out semantics analysis. Download [songlyrics.csv](https://www.kaggle.com/mousehead/songlyrics) from this link.
#
# Larger datasets are available upon request for you to use for your final project. Also, because of Cloud9's limited memory capacity, you will have to find better computational power (Most laptops, although relatively slow, do a decent job at traning neural networks).
