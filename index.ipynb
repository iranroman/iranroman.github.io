# %% [markdown]
# # Irán @ Stanford University #
# <img align="left" src="FullSizeRender.jpg" style="width: 170px" />

# %% [markdown]
# ### About me ###
#
# I am a computational/theoretical neuroscientist.
# [comment]: <> (Add CV using a shareable pdf from Overleaf)
#
# ### Ways to contact ##
# iran ~at~ ccrma.stanford.edu
# [comment]: <> (Include links to all social media)
#
# ---
# ## Activity Thread ##

# %% [markdown]
# ### [2018] Deep Learning Engineer @ Apple
# Developed Deep Neural Networks for Siri at [Apple](http://www.Apple.com) in Cupertino, California

# %% [markdown]
# ###  [2018] Deep Learning for MIR Workshops @ CCRMA (Summer)
# Co-taught with [Kitty Shi](https://ccrma.stanford.edu/~kittyshi/) the [Deep Learning for Music Information Retrieval Workshops](DLfMIR_workshop.htm) at the [Center for Computer Research in Music and Acoustics](https://ccrma.stanford.edu) in Stanford, California

# %% [markdown]
# ###  [2018] Neural Networks Worshop @ ITSUR (January)
# Taught a [Neural Networks Workshop (in Spanish)](https://iranroman.github.io/algoritmica/index.html) at the [Higher Technological Institute of Southern Guanajuato](http://www.itsur.edu.mx) in Uriangato, Gto, Mexico

# %% [markdown]
# ###  [2017 - 2018] Signal Processing and Machine Learning Engineer @ Plantronics
# Developed Artificial Neural Networks and Signal Processing Algorithms for Wearable Headsets at [Plantronics](http://www.plantronics.com/us/) in Santa Cruz, California

# %% [markdown]
# ###  [2017] Deep Learning for MIR Workshop @ CCRMA (Summer)
# Taught (with [Ankita Mitra](https://www.linkedin.com/in/mitraankita/) and [Anish Nag](http://anishnag.com)) the [Deep Learning for Music Information Retrieval Workshop](DLfMIR_workshop.htm) at the [Center for Computer Research in Music and Acoustics](https://ccrma.stanford.edu) in Stanford, California

# %% [markdown]
# ###  [2017] Machine Learning Intern @ Allocate.ai (Summer)
# Built Artificial Neural Networks for cool data science projects at [Allocate.ai](https://allocate.ai) in San Francisco, California
